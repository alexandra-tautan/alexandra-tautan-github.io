# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandra-tautan/alexandra-tautan.github.io/blob/master/ClassifyEpilepticSeizures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import

# %%
import pandas as pd 
import numpy as np 
import os
from sklearn.model_selection import StratifiedKFold
from keras import backend as K
import keras
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Read Data

# %%
ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# Extract Features

# %% [markdown]
# Decorrelate Data

# %% [markdown]
# Classification

# %% [markdown]
# Accuracy
